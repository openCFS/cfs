# %%
import os
import gmsh
import numpy as np
import typing
import pandas as pd
import re
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import sys 
sys.path.append("./")

class SensorArray:
    def __init__(self,filename: str) -> None:
        data = np.loadtxt(filename,delimiter=",",skiprows=1)
        self.NumberDatapoints = np.size(data,0)
        self.NodeCoordinates = data[:,1:4]
        self.RealValue = data[:,4:7]
        self.ElementCoordinates = data[:,7:10]
    
    def getNodeCoordinates(self,idx:  typing.Optional[np.ndarray] = None) -> np.ndarray:
        if idx == None:
            return self.NodeCoordinates[:,:]
        else:
            if not np.issubdtype(idx.dtype, np.integer):  
                raise ValueError("Index array must contain integers.")

            if np.any(idx < 0) or np.any(idx >= self.NumberDatapoints):  
                raise IndexError("Index out of range.")
            
            return self.NodeCoordinates[idx, :]
        
    def getElementCoordinates(self,idx:  typing.Optional[np.ndarray] = None) -> np.ndarray:
        if idx == None:
            return self.ElementCoordinates[:,:]
        else:
            if not np.issubdtype(idx.dtype, np.integer):  
                raise ValueError("Index array must contain integers.")

            if np.any(idx < 0) or np.any(idx >= self.NumberDatapoints):  
                raise IndexError("Index out of range.")
            
            return self.ElementCoordinates[idx, :]
        
def OperaTable(filename):
    with open(filename, "r") as file:
        lines = file.readlines()
    
    # Dewtermine number of datapoints
    first_line = lines[0].strip()
    counts = list(map(int, first_line.split()))
    num_data_points = counts[0] * counts[1] * counts[2] 
    
    # Extract Header
    column_names = []
    for line in lines[1:]:
        line = line.strip()
        if line == "0":  # Ende des Headers
            break
        column_name = re.sub(r"^\d+\s+|\[.*?\]", "", line).strip() 
        column_names.append(column_name)
    
    # Get Data
    data_start_index = lines.index(" 0\n") + 1  # First index after row with "0\n"
    data_lines = lines[data_start_index:data_start_index + num_data_points]
    
    # Convert Data
    data = [list(map(float, line.split())) for line in data_lines]
    df = pd.DataFrame(data, columns=column_names)
    
    return df

# %% [markdown]
# ### Create the Mesh using Gmsh
# For the Validation the following lines in the file "Coil3DVelocityAV.geo" need to be
# - Line 47: k = 12
# - Line 49: q_h = 8
#
# in order to have a better mesh which is similiar to the mesh of the reference solution in the comercial program opera. For the testcase the mesh is much coarser:
# - Line 47: k = 2
# - Line 49: q_h = 1
#
# Additionaly the lines for the mesh-input, the surfRegionResults and the sensorArray need to be uncommented in the Coil3DVelocityAV.xml

# %%
# %%capture output

gmsh.initialize()
gmsh.open(f"Coil3DVelocityAV.geo")
gmsh.model.mesh.generate(3)
gmsh.write(f"Coil3DVelocityAV.msh")
gmsh.finalize()
# Out:
# Info    : Reading 'Coil3DVelocityAV.geo'...
# Info    : Done reading 'Coil3DVelocityAV.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 10%] Meshing curve 12 (Line)
# Info    : [ 10%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 10%] Meshing curve 15 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 17 (Line)
# Info    : [ 10%] Meshing curve 18 (Line)
# Info    : [ 10%] Meshing curve 19 (Line)
# Info    : [ 10%] Meshing curve 20 (Line)
# Info    : [ 10%] Meshing curve 21 (Line)
# Info    : [ 10%] Meshing curve 22 (Line)
# Info    : [ 10%] Meshing curve 23 (Line)
# Info    : [ 10%] Meshing curve 24 (Line)
# Info    : [ 10%] Meshing curve 25 (Line)
# Info    : [ 10%] Meshing curve 26 (Line)
# Info    : [ 10%] Meshing curve 27 (Line)
# Info    : [ 10%] Meshing curve 28 (Line)
# Info    : [ 10%] Meshing curve 29 (Line)
# Info    : [ 10%] Meshing curve 30 (Line)
# Info    : [ 10%] Meshing curve 31 (Line)
# Info    : [ 10%] Meshing curve 32 (Line)
# Info    : [ 10%] Meshing curve 33 (Line)
# Info    : [ 10%] Meshing curve 34 (Line)
# Info    : [ 10%] Meshing curve 35 (Line)
# Info    : [ 10%] Meshing curve 36 (Line)
# Info    : [ 10%] Meshing curve 37 (Line)
# Info    : [ 10%] Meshing curve 38 (Line)
# Info    : [ 10%] Meshing curve 39 (Line)
# Info    : [ 10%] Meshing curve 40 (Line)
# Info    : [ 10%] Meshing curve 41 (Line)
# Info    : [ 10%] Meshing curve 42 (Line)
# Info    : [ 10%] Meshing curve 43 (Line)
# Info    : [ 10%] Meshing curve 44 (Line)
# Info    : [ 10%] Meshing curve 45 (Line)
# Info    : [ 10%] Meshing curve 46 (Line)
# Info    : [ 10%] Meshing curve 47 (Line)
# Info    : [ 10%] Meshing curve 48 (Line)
# Info    : [ 10%] Meshing curve 49 (Line)
# Info    : [ 10%] Meshing curve 50 (Line)
# Info    : [ 10%] Meshing curve 51 (Line)
# Info    : [ 10%] Meshing curve 52 (Line)
# Info    : [ 10%] Meshing curve 53 (Line)
# Info    : [ 10%] Meshing curve 54 (Line)
# Info    : [ 10%] Meshing curve 55 (Line)
# Info    : [ 10%] Meshing curve 56 (Line)
# Info    : [ 10%] Meshing curve 57 (Line)
# Info    : [ 10%] Meshing curve 58 (Line)
# Info    : [ 10%] Meshing curve 59 (Line)
# Info    : [ 10%] Meshing curve 60 (Line)
# Info    : [ 10%] Meshing curve 61 (Line)
# Info    : [ 10%] Meshing curve 62 (Line)
# Info    : [ 10%] Meshing curve 63 (Line)
# Info    : [ 10%] Meshing curve 64 (Line)
# Info    : [ 10%] Meshing curve 65 (Line)
# Info    : [ 10%] Meshing curve 66 (Line)
# Info    : [ 20%] Meshing curve 67 (Line)
# Info    : [ 20%] Meshing curve 68 (Line)
# Info    : [ 20%] Meshing curve 69 (Line)
# Info    : [ 20%] Meshing curve 70 (Line)
# Info    : [ 20%] Meshing curve 71 (Line)
# Info    : [ 20%] Meshing curve 72 (Line)
# Info    : [ 20%] Meshing curve 73 (Line)
# Info    : [ 20%] Meshing curve 74 (Line)
# Info    : [ 20%] Meshing curve 75 (Line)
# Info    : [ 20%] Meshing curve 76 (Line)
# Info    : [ 20%] Meshing curve 77 (Line)
# Info    : [ 20%] Meshing curve 78 (Line)
# Info    : [ 20%] Meshing curve 79 (Line)
# Info    : [ 20%] Meshing curve 80 (Line)
# Info    : [ 20%] Meshing curve 81 (Line)
# Info    : [ 20%] Meshing curve 82 (Line)
# Info    : [ 20%] Meshing curve 83 (Line)
# Info    : [ 20%] Meshing curve 84 (Line)
# Info    : [ 20%] Meshing curve 85 (Line)
# Info    : [ 20%] Meshing curve 86 (Line)
# Info    : [ 20%] Meshing curve 87 (Line)
# Info    : [ 20%] Meshing curve 88 (Line)
# Info    : [ 20%] Meshing curve 89 (Line)
# Info    : [ 20%] Meshing curve 90 (Line)
# Info    : [ 20%] Meshing curve 91 (Line)
# Info    : [ 20%] Meshing curve 92 (Line)
# Info    : [ 20%] Meshing curve 93 (Line)
# Info    : [ 20%] Meshing curve 94 (Line)
# Info    : [ 20%] Meshing curve 95 (Line)
# Info    : [ 20%] Meshing curve 96 (Line)
# Info    : [ 20%] Meshing curve 97 (Line)
# Info    : [ 20%] Meshing curve 98 (Line)
# Info    : [ 20%] Meshing curve 99 (Line)
# Info    : [ 20%] Meshing curve 100 (Line)
# Info    : [ 20%] Meshing curve 101 (Line)
# Info    : [ 20%] Meshing curve 102 (Line)
# Info    : [ 20%] Meshing curve 103 (Line)
# Info    : [ 20%] Meshing curve 104 (Line)
# Info    : [ 20%] Meshing curve 105 (Line)
# Info    : [ 20%] Meshing curve 106 (Line)
# Info    : [ 20%] Meshing curve 107 (Line)
# Info    : [ 20%] Meshing curve 108 (Line)
# Info    : [ 20%] Meshing curve 109 (Line)
# Info    : [ 20%] Meshing curve 110 (Line)
# Info    : [ 20%] Meshing curve 111 (Line)
# Info    : [ 20%] Meshing curve 112 (Line)
# Info    : [ 20%] Meshing curve 113 (Line)
# Info    : [ 20%] Meshing curve 114 (Line)
# Info    : [ 20%] Meshing curve 115 (Line)
# Info    : [ 20%] Meshing curve 117 (Extruded)
# Info    : [ 20%] Meshing curve 118 (Extruded)
# Info    : [ 20%] Meshing curve 119 (Extruded)
# Info    : [ 20%] Meshing curve 120 (Extruded)
# Info    : [ 20%] Meshing curve 122 (Extruded)
# Info    : [ 20%] Meshing curve 123 (Extruded)
# Info    : [ 20%] Meshing curve 127 (Extruded)
# Info    : [ 20%] Meshing curve 131 (Extruded)
# Info    : [ 20%] Meshing curve 140 (Extruded)
# Info    : [ 20%] Meshing curve 141 (Extruded)
# Info    : [ 20%] Meshing curve 142 (Extruded)
# Info    : [ 20%] Meshing curve 149 (Extruded)
# Info    : [ 20%] Meshing curve 153 (Extruded)
# Info    : [ 20%] Meshing curve 162 (Extruded)
# Info    : [ 20%] Meshing curve 163 (Extruded)
# Info    : [ 20%] Meshing curve 164 (Extruded)
# Info    : [ 20%] Meshing curve 171 (Extruded)
# Info    : [ 30%] Meshing curve 175 (Extruded)
# Info    : [ 30%] Meshing curve 184 (Extruded)
# Info    : [ 30%] Meshing curve 185 (Extruded)
# Info    : [ 30%] Meshing curve 186 (Extruded)
# Info    : [ 30%] Meshing curve 193 (Extruded)
# Info    : [ 30%] Meshing curve 197 (Extruded)
# Info    : [ 30%] Meshing curve 206 (Extruded)
# Info    : [ 30%] Meshing curve 207 (Extruded)
# Info    : [ 30%] Meshing curve 208 (Extruded)
# Info    : [ 30%] Meshing curve 215 (Extruded)
# Info    : [ 30%] Meshing curve 219 (Extruded)
# Info    : [ 30%] Meshing curve 228 (Extruded)
# Info    : [ 30%] Meshing curve 229 (Extruded)
# Info    : [ 30%] Meshing curve 230 (Extruded)
# Info    : [ 30%] Meshing curve 237 (Extruded)
# Info    : [ 30%] Meshing curve 241 (Extruded)
# Info    : [ 30%] Meshing curve 250 (Extruded)
# Info    : [ 30%] Meshing curve 251 (Extruded)
# Info    : [ 30%] Meshing curve 252 (Extruded)
# Info    : [ 30%] Meshing curve 259 (Extruded)
# Info    : [ 30%] Meshing curve 263 (Extruded)
# Info    : [ 30%] Meshing curve 272 (Extruded)
# Info    : [ 30%] Meshing curve 273 (Extruded)
# Info    : [ 30%] Meshing curve 274 (Extruded)
# Info    : [ 30%] Meshing curve 281 (Extruded)
# Info    : [ 30%] Meshing curve 285 (Extruded)
# Info    : [ 30%] Meshing curve 294 (Extruded)
# Info    : [ 30%] Meshing curve 295 (Extruded)
# Info    : [ 30%] Meshing curve 296 (Extruded)
# Info    : [ 30%] Meshing curve 303 (Extruded)
# Info    : [ 30%] Meshing curve 307 (Extruded)
# Info    : [ 30%] Meshing curve 316 (Extruded)
# Info    : [ 30%] Meshing curve 317 (Extruded)
# Info    : [ 30%] Meshing curve 318 (Extruded)
# Info    : [ 30%] Meshing curve 325 (Extruded)
# Info    : [ 30%] Meshing curve 329 (Extruded)
# Info    : [ 30%] Meshing curve 337 (Extruded)
# Info    : [ 30%] Meshing curve 338 (Extruded)
# Info    : [ 30%] Meshing curve 339 (Extruded)
# Info    : [ 30%] Meshing curve 343 (Extruded)
# Info    : [ 30%] Meshing curve 347 (Extruded)
# Info    : [ 30%] Meshing curve 360 (Extruded)
# Info    : [ 30%] Meshing curve 361 (Extruded)
# Info    : [ 30%] Meshing curve 369 (Extruded)
# Info    : [ 30%] Meshing curve 382 (Extruded)
# Info    : [ 30%] Meshing curve 383 (Extruded)
# Info    : [ 30%] Meshing curve 391 (Extruded)
# Info    : [ 30%] Meshing curve 404 (Extruded)
# Info    : [ 30%] Meshing curve 405 (Extruded)
# Info    : [ 30%] Meshing curve 413 (Extruded)
# Info    : [ 30%] Meshing curve 426 (Extruded)
# Info    : [ 30%] Meshing curve 427 (Extruded)
# Info    : [ 30%] Meshing curve 435 (Extruded)
# Info    : [ 30%] Meshing curve 448 (Extruded)
# Info    : [ 30%] Meshing curve 449 (Extruded)
# Info    : [ 30%] Meshing curve 457 (Extruded)
# Info    : [ 30%] Meshing curve 470 (Extruded)
# Info    : [ 30%] Meshing curve 471 (Extruded)
# Info    : [ 30%] Meshing curve 479 (Extruded)
# Info    : [ 30%] Meshing curve 492 (Extruded)
# Info    : [ 30%] Meshing curve 493 (Extruded)
# Info    : [ 30%] Meshing curve 501 (Extruded)
# Info    : [ 30%] Meshing curve 514 (Extruded)
# Info    : [ 30%] Meshing curve 515 (Extruded)
# Info    : [ 30%] Meshing curve 523 (Extruded)
# Info    : [ 30%] Meshing curve 536 (Extruded)
# Info    : [ 40%] Meshing curve 537 (Extruded)
# Info    : [ 40%] Meshing curve 545 (Extruded)
# Info    : [ 40%] Meshing curve 557 (Extruded)
# Info    : [ 40%] Meshing curve 558 (Extruded)
# Info    : [ 40%] Meshing curve 559 (Extruded)
# Info    : [ 40%] Meshing curve 563 (Extruded)
# Info    : [ 40%] Meshing curve 567 (Extruded)
# Info    : [ 40%] Meshing curve 580 (Extruded)
# Info    : [ 40%] Meshing curve 581 (Extruded)
# Info    : [ 40%] Meshing curve 589 (Extruded)
# Info    : [ 40%] Meshing curve 602 (Extruded)
# Info    : [ 40%] Meshing curve 603 (Extruded)
# Info    : [ 40%] Meshing curve 611 (Extruded)
# Info    : [ 40%] Meshing curve 624 (Extruded)
# Info    : [ 40%] Meshing curve 625 (Extruded)
# Info    : [ 40%] Meshing curve 633 (Extruded)
# Info    : [ 40%] Meshing curve 646 (Extruded)
# Info    : [ 40%] Meshing curve 647 (Extruded)
# Info    : [ 40%] Meshing curve 655 (Extruded)
# Info    : [ 40%] Meshing curve 668 (Extruded)
# Info    : [ 40%] Meshing curve 669 (Extruded)
# Info    : [ 40%] Meshing curve 677 (Extruded)
# Info    : [ 40%] Meshing curve 690 (Extruded)
# Info    : [ 40%] Meshing curve 691 (Extruded)
# Info    : [ 40%] Meshing curve 699 (Extruded)
# Info    : [ 40%] Meshing curve 712 (Extruded)
# Info    : [ 40%] Meshing curve 713 (Extruded)
# Info    : [ 40%] Meshing curve 721 (Extruded)
# Info    : [ 40%] Meshing curve 734 (Extruded)
# Info    : [ 40%] Meshing curve 735 (Extruded)
# Info    : [ 40%] Meshing curve 743 (Extruded)
# Info    : [ 40%] Meshing curve 756 (Extruded)
# Info    : [ 40%] Meshing curve 757 (Extruded)
# Info    : [ 40%] Meshing curve 765 (Extruded)
# Info    : [ 40%] Meshing curve 777 (Extruded)
# Info    : [ 40%] Meshing curve 778 (Extruded)
# Info    : [ 40%] Meshing curve 779 (Extruded)
# Info    : [ 40%] Meshing curve 783 (Extruded)
# Info    : [ 40%] Meshing curve 787 (Extruded)
# Info    : [ 40%] Meshing curve 800 (Extruded)
# Info    : [ 40%] Meshing curve 801 (Extruded)
# Info    : [ 40%] Meshing curve 809 (Extruded)
# Info    : [ 40%] Meshing curve 822 (Extruded)
# Info    : [ 40%] Meshing curve 823 (Extruded)
# Info    : [ 40%] Meshing curve 831 (Extruded)
# Info    : [ 40%] Meshing curve 844 (Extruded)
# Info    : [ 40%] Meshing curve 845 (Extruded)
# Info    : [ 40%] Meshing curve 853 (Extruded)
# Info    : [ 40%] Meshing curve 866 (Extruded)
# Info    : [ 40%] Meshing curve 867 (Extruded)
# Info    : [ 40%] Meshing curve 875 (Extruded)
# Info    : [ 40%] Meshing curve 888 (Extruded)
# Info    : [ 40%] Meshing curve 889 (Extruded)
# Info    : [ 40%] Meshing curve 897 (Extruded)
# Info    : [ 40%] Meshing curve 910 (Extruded)
# Info    : [ 40%] Meshing curve 911 (Extruded)
# Info    : [ 40%] Meshing curve 919 (Extruded)
# Info    : [ 40%] Meshing curve 932 (Extruded)
# Info    : [ 40%] Meshing curve 933 (Extruded)
# Info    : [ 40%] Meshing curve 941 (Extruded)
# Info    : [ 40%] Meshing curve 954 (Extruded)
# Info    : [ 40%] Meshing curve 955 (Extruded)
# Info    : [ 40%] Meshing curve 963 (Extruded)
# Info    : [ 40%] Meshing curve 976 (Extruded)
# Info    : [ 40%] Meshing curve 977 (Extruded)
# Info    : [ 40%] Meshing curve 985 (Extruded)
# Info    : [ 50%] Meshing curve 997 (Extruded)
# Info    : [ 50%] Meshing curve 998 (Extruded)
# Info    : [ 50%] Meshing curve 999 (Extruded)
# Info    : [ 50%] Meshing curve 1003 (Extruded)
# Info    : [ 50%] Meshing curve 1007 (Extruded)
# Info    : [ 50%] Meshing curve 1020 (Extruded)
# Info    : [ 50%] Meshing curve 1021 (Extruded)
# Info    : [ 50%] Meshing curve 1029 (Extruded)
# Info    : [ 50%] Meshing curve 1042 (Extruded)
# Info    : [ 50%] Meshing curve 1043 (Extruded)
# Info    : [ 50%] Meshing curve 1051 (Extruded)
# Info    : [ 50%] Meshing curve 1064 (Extruded)
# Info    : [ 50%] Meshing curve 1065 (Extruded)
# Info    : [ 50%] Meshing curve 1073 (Extruded)
# Info    : [ 50%] Meshing curve 1086 (Extruded)
# Info    : [ 50%] Meshing curve 1087 (Extruded)
# Info    : [ 50%] Meshing curve 1095 (Extruded)
# Info    : [ 50%] Meshing curve 1108 (Extruded)
# Info    : [ 50%] Meshing curve 1109 (Extruded)
# Info    : [ 50%] Meshing curve 1117 (Extruded)
# Info    : [ 50%] Meshing curve 1130 (Extruded)
# Info    : [ 50%] Meshing curve 1131 (Extruded)
# Info    : [ 50%] Meshing curve 1139 (Extruded)
# Info    : [ 50%] Meshing curve 1152 (Extruded)
# Info    : [ 50%] Meshing curve 1153 (Extruded)
# Info    : [ 50%] Meshing curve 1161 (Extruded)
# Info    : [ 50%] Meshing curve 1174 (Extruded)
# Info    : [ 50%] Meshing curve 1175 (Extruded)
# Info    : [ 50%] Meshing curve 1183 (Extruded)
# Info    : [ 50%] Meshing curve 1196 (Extruded)
# Info    : [ 50%] Meshing curve 1197 (Extruded)
# Info    : [ 50%] Meshing curve 1205 (Extruded)
# Info    : [ 50%] Meshing curve 1217 (Extruded)
# Info    : [ 50%] Meshing curve 1218 (Extruded)
# Info    : [ 50%] Meshing curve 1219 (Extruded)
# Info    : [ 50%] Meshing curve 1220 (Extruded)
# Info    : [ 50%] Meshing curve 1222 (Extruded)
# Info    : [ 50%] Meshing curve 1223 (Extruded)
# Info    : [ 50%] Meshing curve 1227 (Extruded)
# Info    : [ 50%] Meshing curve 1231 (Extruded)
# Info    : [ 50%] Meshing curve 1240 (Extruded)
# Info    : [ 50%] Meshing curve 1241 (Extruded)
# Info    : [ 50%] Meshing curve 1242 (Extruded)
# Info    : [ 50%] Meshing curve 1249 (Extruded)
# Info    : [ 50%] Meshing curve 1253 (Extruded)
# Info    : [ 50%] Meshing curve 1262 (Extruded)
# Info    : [ 50%] Meshing curve 1263 (Extruded)
# Info    : [ 50%] Meshing curve 1264 (Extruded)
# Info    : [ 50%] Meshing curve 1271 (Extruded)
# Info    : [ 50%] Meshing curve 1275 (Extruded)
# Info    : [ 50%] Meshing curve 1284 (Extruded)
# Info    : [ 50%] Meshing curve 1285 (Extruded)
# Info    : [ 50%] Meshing curve 1286 (Extruded)
# Info    : [ 50%] Meshing curve 1293 (Extruded)
# Info    : [ 50%] Meshing curve 1297 (Extruded)
# Info    : [ 50%] Meshing curve 1306 (Extruded)
# Info    : [ 50%] Meshing curve 1307 (Extruded)
# Info    : [ 50%] Meshing curve 1308 (Extruded)
# Info    : [ 50%] Meshing curve 1315 (Extruded)
# Info    : [ 50%] Meshing curve 1319 (Extruded)
# Info    : [ 50%] Meshing curve 1328 (Extruded)
# Info    : [ 50%] Meshing curve 1329 (Extruded)
# Info    : [ 50%] Meshing curve 1330 (Extruded)
# Info    : [ 50%] Meshing curve 1337 (Extruded)
# Info    : [ 50%] Meshing curve 1341 (Extruded)
# Info    : [ 60%] Meshing curve 1350 (Extruded)
# Info    : [ 60%] Meshing curve 1351 (Extruded)
# Info    : [ 60%] Meshing curve 1352 (Extruded)
# Info    : [ 60%] Meshing curve 1359 (Extruded)
# Info    : [ 60%] Meshing curve 1363 (Extruded)
# Info    : [ 60%] Meshing curve 1372 (Extruded)
# Info    : [ 60%] Meshing curve 1373 (Extruded)
# Info    : [ 60%] Meshing curve 1374 (Extruded)
# Info    : [ 60%] Meshing curve 1381 (Extruded)
# Info    : [ 60%] Meshing curve 1385 (Extruded)
# Info    : [ 60%] Meshing curve 1394 (Extruded)
# Info    : [ 60%] Meshing curve 1395 (Extruded)
# Info    : [ 60%] Meshing curve 1396 (Extruded)
# Info    : [ 60%] Meshing curve 1403 (Extruded)
# Info    : [ 60%] Meshing curve 1407 (Extruded)
# Info    : [ 60%] Meshing curve 1416 (Extruded)
# Info    : [ 60%] Meshing curve 1417 (Extruded)
# Info    : [ 60%] Meshing curve 1418 (Extruded)
# Info    : [ 60%] Meshing curve 1425 (Extruded)
# Info    : [ 60%] Meshing curve 1429 (Extruded)
# Info    : [ 60%] Meshing curve 1437 (Extruded)
# Info    : [ 60%] Meshing curve 1438 (Extruded)
# Info    : [ 60%] Meshing curve 1439 (Extruded)
# Info    : [ 60%] Meshing curve 1443 (Extruded)
# Info    : [ 60%] Meshing curve 1447 (Extruded)
# Info    : [ 60%] Meshing curve 1460 (Extruded)
# Info    : [ 60%] Meshing curve 1461 (Extruded)
# Info    : [ 60%] Meshing curve 1469 (Extruded)
# Info    : [ 60%] Meshing curve 1482 (Extruded)
# Info    : [ 60%] Meshing curve 1483 (Extruded)
# Info    : [ 60%] Meshing curve 1491 (Extruded)
# Info    : [ 60%] Meshing curve 1504 (Extruded)
# Info    : [ 60%] Meshing curve 1505 (Extruded)
# Info    : [ 60%] Meshing curve 1513 (Extruded)
# Info    : [ 60%] Meshing curve 1526 (Extruded)
# Info    : [ 60%] Meshing curve 1527 (Extruded)
# Info    : [ 60%] Meshing curve 1535 (Extruded)
# Info    : [ 60%] Meshing curve 1548 (Extruded)
# Info    : [ 60%] Meshing curve 1549 (Extruded)
# Info    : [ 60%] Meshing curve 1557 (Extruded)
# Info    : [ 60%] Meshing curve 1570 (Extruded)
# Info    : [ 60%] Meshing curve 1571 (Extruded)
# Info    : [ 60%] Meshing curve 1579 (Extruded)
# Info    : [ 60%] Meshing curve 1592 (Extruded)
# Info    : [ 60%] Meshing curve 1593 (Extruded)
# Info    : [ 60%] Meshing curve 1601 (Extruded)
# Info    : [ 60%] Meshing curve 1614 (Extruded)
# Info    : [ 60%] Meshing curve 1615 (Extruded)
# Info    : [ 60%] Meshing curve 1623 (Extruded)
# Info    : [ 60%] Meshing curve 1636 (Extruded)
# Info    : [ 60%] Meshing curve 1637 (Extruded)
# Info    : [ 60%] Meshing curve 1645 (Extruded)
# Info    : [ 60%] Meshing curve 1657 (Extruded)
# Info    : [ 60%] Meshing curve 1658 (Extruded)
# Info    : [ 60%] Meshing curve 1659 (Extruded)
# Info    : [ 60%] Meshing curve 1663 (Extruded)
# Info    : [ 60%] Meshing curve 1667 (Extruded)
# Info    : [ 60%] Meshing curve 1680 (Extruded)
# Info    : [ 60%] Meshing curve 1681 (Extruded)
# Info    : [ 60%] Meshing curve 1689 (Extruded)
# Info    : [ 60%] Meshing curve 1702 (Extruded)
# Info    : [ 60%] Meshing curve 1703 (Extruded)
# Info    : [ 60%] Meshing curve 1711 (Extruded)
# Info    : [ 60%] Meshing curve 1724 (Extruded)
# Info    : [ 60%] Meshing curve 1725 (Extruded)
# Info    : [ 60%] Meshing curve 1733 (Extruded)
# Info    : [ 70%] Meshing curve 1746 (Extruded)
# Info    : [ 70%] Meshing curve 1747 (Extruded)
# Info    : [ 70%] Meshing curve 1755 (Extruded)
# Info    : [ 70%] Meshing curve 1768 (Extruded)
# Info    : [ 70%] Meshing curve 1769 (Extruded)
# Info    : [ 70%] Meshing curve 1777 (Extruded)
# Info    : [ 70%] Meshing curve 1790 (Extruded)
# Info    : [ 70%] Meshing curve 1791 (Extruded)
# Info    : [ 70%] Meshing curve 1799 (Extruded)
# Info    : [ 70%] Meshing curve 1812 (Extruded)
# Info    : [ 70%] Meshing curve 1813 (Extruded)
# Info    : [ 70%] Meshing curve 1821 (Extruded)
# Info    : [ 70%] Meshing curve 1834 (Extruded)
# Info    : [ 70%] Meshing curve 1835 (Extruded)
# Info    : [ 70%] Meshing curve 1843 (Extruded)
# Info    : [ 70%] Meshing curve 1856 (Extruded)
# Info    : [ 70%] Meshing curve 1857 (Extruded)
# Info    : [ 70%] Meshing curve 1865 (Extruded)
# Info    : [ 70%] Meshing curve 1877 (Extruded)
# Info    : [ 70%] Meshing curve 1878 (Extruded)
# Info    : [ 70%] Meshing curve 1879 (Extruded)
# Info    : [ 70%] Meshing curve 1883 (Extruded)
# Info    : [ 70%] Meshing curve 1887 (Extruded)
# Info    : [ 70%] Meshing curve 1900 (Extruded)
# Info    : [ 70%] Meshing curve 1901 (Extruded)
# Info    : [ 70%] Meshing curve 1909 (Extruded)
# Info    : [ 70%] Meshing curve 1922 (Extruded)
# Info    : [ 70%] Meshing curve 1923 (Extruded)
# Info    : [ 70%] Meshing curve 1931 (Extruded)
# Info    : [ 70%] Meshing curve 1944 (Extruded)
# Info    : [ 70%] Meshing curve 1945 (Extruded)
# Info    : [ 70%] Meshing curve 1953 (Extruded)
# Info    : [ 70%] Meshing curve 1966 (Extruded)
# Info    : [ 70%] Meshing curve 1967 (Extruded)
# Info    : [ 70%] Meshing curve 1975 (Extruded)
# Info    : [ 70%] Meshing curve 1988 (Extruded)
# Info    : [ 70%] Meshing curve 1989 (Extruded)
# Info    : [ 70%] Meshing curve 1997 (Extruded)
# Info    : [ 70%] Meshing curve 2010 (Extruded)
# Info    : [ 70%] Meshing curve 2011 (Extruded)
# Info    : [ 70%] Meshing curve 2019 (Extruded)
# Info    : [ 70%] Meshing curve 2032 (Extruded)
# Info    : [ 70%] Meshing curve 2033 (Extruded)
# Info    : [ 70%] Meshing curve 2041 (Extruded)
# Info    : [ 70%] Meshing curve 2054 (Extruded)
# Info    : [ 70%] Meshing curve 2055 (Extruded)
# Info    : [ 70%] Meshing curve 2063 (Extruded)
# Info    : [ 70%] Meshing curve 2076 (Extruded)
# Info    : [ 70%] Meshing curve 2077 (Extruded)
# Info    : [ 70%] Meshing curve 2085 (Extruded)
# Info    : [ 70%] Meshing curve 2097 (Extruded)
# Info    : [ 70%] Meshing curve 2098 (Extruded)
# Info    : [ 70%] Meshing curve 2099 (Extruded)
# Info    : [ 70%] Meshing curve 2103 (Extruded)
# Info    : [ 70%] Meshing curve 2107 (Extruded)
# Info    : [ 70%] Meshing curve 2120 (Extruded)
# Info    : [ 70%] Meshing curve 2121 (Extruded)
# Info    : [ 70%] Meshing curve 2129 (Extruded)
# Info    : [ 70%] Meshing curve 2142 (Extruded)
# Info    : [ 70%] Meshing curve 2143 (Extruded)
# Info    : [ 70%] Meshing curve 2151 (Extruded)
# Info    : [ 70%] Meshing curve 2164 (Extruded)
# Info    : [ 70%] Meshing curve 2165 (Extruded)
# Info    : [ 70%] Meshing curve 2173 (Extruded)
# Info    : [ 70%] Meshing curve 2186 (Extruded)
# Info    : [ 70%] Meshing curve 2187 (Extruded)
# Info    : [ 80%] Meshing curve 2195 (Extruded)
# Info    : [ 80%] Meshing curve 2208 (Extruded)
# Info    : [ 80%] Meshing curve 2209 (Extruded)
# Info    : [ 80%] Meshing curve 2217 (Extruded)
# Info    : [ 80%] Meshing curve 2230 (Extruded)
# Info    : [ 80%] Meshing curve 2231 (Extruded)
# Info    : [ 80%] Meshing curve 2239 (Extruded)
# Info    : [ 80%] Meshing curve 2252 (Extruded)
# Info    : [ 80%] Meshing curve 2253 (Extruded)
# Info    : [ 80%] Meshing curve 2261 (Extruded)
# Info    : [ 80%] Meshing curve 2274 (Extruded)
# Info    : [ 80%] Meshing curve 2275 (Extruded)
# Info    : [ 80%] Meshing curve 2283 (Extruded)
# Info    : [ 80%] Meshing curve 2296 (Extruded)
# Info    : [ 80%] Meshing curve 2297 (Extruded)
# Info    : [ 80%] Meshing curve 2305 (Extruded)
# Info    : [ 80%] Meshing curve 2317 (Extruded)
# Info    : [ 80%] Meshing curve 2318 (Extruded)
# Info    : [ 80%] Meshing curve 2319 (Extruded)
# Info    : [ 80%] Meshing curve 2320 (Extruded)
# Info    : [ 80%] Meshing curve 2322 (Extruded)
# Info    : [ 80%] Meshing curve 2323 (Extruded)
# Info    : [ 80%] Meshing curve 2327 (Extruded)
# Info    : [ 80%] Meshing curve 2331 (Extruded)
# Info    : [ 80%] Meshing curve 2340 (Extruded)
# Info    : [ 80%] Meshing curve 2341 (Extruded)
# Info    : [ 80%] Meshing curve 2342 (Extruded)
# Info    : [ 80%] Meshing curve 2349 (Extruded)
# Info    : [ 80%] Meshing curve 2353 (Extruded)
# Info    : [ 80%] Meshing curve 2362 (Extruded)
# Info    : [ 80%] Meshing curve 2363 (Extruded)
# Info    : [ 80%] Meshing curve 2364 (Extruded)
# Info    : [ 80%] Meshing curve 2371 (Extruded)
# Info    : [ 80%] Meshing curve 2375 (Extruded)
# Info    : [ 80%] Meshing curve 2384 (Extruded)
# Info    : [ 80%] Meshing curve 2385 (Extruded)
# Info    : [ 80%] Meshing curve 2386 (Extruded)
# Info    : [ 80%] Meshing curve 2393 (Extruded)
# Info    : [ 80%] Meshing curve 2397 (Extruded)
# Info    : [ 80%] Meshing curve 2406 (Extruded)
# Info    : [ 80%] Meshing curve 2407 (Extruded)
# Info    : [ 80%] Meshing curve 2408 (Extruded)
# Info    : [ 80%] Meshing curve 2415 (Extruded)
# Info    : [ 80%] Meshing curve 2419 (Extruded)
# Info    : [ 80%] Meshing curve 2428 (Extruded)
# Info    : [ 80%] Meshing curve 2429 (Extruded)
# Info    : [ 80%] Meshing curve 2430 (Extruded)
# Info    : [ 80%] Meshing curve 2437 (Extruded)
# Info    : [ 80%] Meshing curve 2441 (Extruded)
# Info    : [ 80%] Meshing curve 2450 (Extruded)
# Info    : [ 80%] Meshing curve 2451 (Extruded)
# Info    : [ 80%] Meshing curve 2452 (Extruded)
# Info    : [ 80%] Meshing curve 2459 (Extruded)
# Info    : [ 80%] Meshing curve 2463 (Extruded)
# Info    : [ 80%] Meshing curve 2472 (Extruded)
# Info    : [ 80%] Meshing curve 2473 (Extruded)
# Info    : [ 80%] Meshing curve 2474 (Extruded)
# Info    : [ 80%] Meshing curve 2481 (Extruded)
# Info    : [ 80%] Meshing curve 2485 (Extruded)
# Info    : [ 80%] Meshing curve 2494 (Extruded)
# Info    : [ 80%] Meshing curve 2495 (Extruded)
# Info    : [ 80%] Meshing curve 2496 (Extruded)
# Info    : [ 80%] Meshing curve 2503 (Extruded)
# Info    : [ 80%] Meshing curve 2507 (Extruded)
# Info    : [ 80%] Meshing curve 2516 (Extruded)
# Info    : [ 80%] Meshing curve 2517 (Extruded)
# Info    : [ 90%] Meshing curve 2518 (Extruded)
# Info    : [ 90%] Meshing curve 2525 (Extruded)
# Info    : [ 90%] Meshing curve 2529 (Extruded)
# Info    : [ 90%] Meshing curve 2537 (Extruded)
# Info    : [ 90%] Meshing curve 2538 (Extruded)
# Info    : [ 90%] Meshing curve 2539 (Extruded)
# Info    : [ 90%] Meshing curve 2543 (Extruded)
# Info    : [ 90%] Meshing curve 2547 (Extruded)
# Info    : [ 90%] Meshing curve 2560 (Extruded)
# Info    : [ 90%] Meshing curve 2561 (Extruded)
# Info    : [ 90%] Meshing curve 2569 (Extruded)
# Info    : [ 90%] Meshing curve 2582 (Extruded)
# Info    : [ 90%] Meshing curve 2583 (Extruded)
# Info    : [ 90%] Meshing curve 2591 (Extruded)
# Info    : [ 90%] Meshing curve 2604 (Extruded)
# Info    : [ 90%] Meshing curve 2605 (Extruded)
# Info    : [ 90%] Meshing curve 2613 (Extruded)
# Info    : [ 90%] Meshing curve 2626 (Extruded)
# Info    : [ 90%] Meshing curve 2627 (Extruded)
# Info    : [ 90%] Meshing curve 2635 (Extruded)
# Info    : [ 90%] Meshing curve 2648 (Extruded)
# Info    : [ 90%] Meshing curve 2649 (Extruded)
# Info    : [ 90%] Meshing curve 2657 (Extruded)
# Info    : [ 90%] Meshing curve 2670 (Extruded)
# Info    : [ 90%] Meshing curve 2671 (Extruded)
# Info    : [ 90%] Meshing curve 2679 (Extruded)
# Info    : [ 90%] Meshing curve 2692 (Extruded)
# Info    : [ 90%] Meshing curve 2693 (Extruded)
# Info    : [ 90%] Meshing curve 2701 (Extruded)
# Info    : [ 90%] Meshing curve 2714 (Extruded)
# Info    : [ 90%] Meshing curve 2715 (Extruded)
# Info    : [ 90%] Meshing curve 2723 (Extruded)
# Info    : [ 90%] Meshing curve 2736 (Extruded)
# Info    : [ 90%] Meshing curve 2737 (Extruded)
# Info    : [ 90%] Meshing curve 2745 (Extruded)
# Info    : [ 90%] Meshing curve 2757 (Extruded)
# Info    : [ 90%] Meshing curve 2758 (Extruded)
# Info    : [ 90%] Meshing curve 2759 (Extruded)
# Info    : [ 90%] Meshing curve 2763 (Extruded)
# Info    : [ 90%] Meshing curve 2767 (Extruded)
# Info    : [ 90%] Meshing curve 2780 (Extruded)
# Info    : [ 90%] Meshing curve 2781 (Extruded)
# Info    : [ 90%] Meshing curve 2789 (Extruded)
# Info    : [ 90%] Meshing curve 2802 (Extruded)
# Info    : [ 90%] Meshing curve 2803 (Extruded)
# Info    : [ 90%] Meshing curve 2811 (Extruded)
# Info    : [ 90%] Meshing curve 2824 (Extruded)
# Info    : [ 90%] Meshing curve 2825 (Extruded)
# Info    : [ 90%] Meshing curve 2833 (Extruded)
# Info    : [ 90%] Meshing curve 2846 (Extruded)
# Info    : [ 90%] Meshing curve 2847 (Extruded)
# Info    : [ 90%] Meshing curve 2855 (Extruded)
# Info    : [ 90%] Meshing curve 2868 (Extruded)
# Info    : [ 90%] Meshing curve 2869 (Extruded)
# Info    : [ 90%] Meshing curve 2877 (Extruded)
# Info    : [ 90%] Meshing curve 2890 (Extruded)
# Info    : [ 90%] Meshing curve 2891 (Extruded)
# Info    : [ 90%] Meshing curve 2899 (Extruded)
# Info    : [ 90%] Meshing curve 2912 (Extruded)
# Info    : [ 90%] Meshing curve 2913 (Extruded)
# Info    : [ 90%] Meshing curve 2921 (Extruded)
# Info    : [ 90%] Meshing curve 2934 (Extruded)
# Info    : [ 90%] Meshing curve 2935 (Extruded)
# Info    : [ 90%] Meshing curve 2943 (Extruded)
# Info    : [ 90%] Meshing curve 2956 (Extruded)
# Info    : [ 90%] Meshing curve 2957 (Extruded)
# Info    : [100%] Meshing curve 2965 (Extruded)
# Info    : [100%] Meshing curve 2977 (Extruded)
# Info    : [100%] Meshing curve 2978 (Extruded)
# Info    : [100%] Meshing curve 2979 (Extruded)
# Info    : [100%] Meshing curve 2983 (Extruded)
# Info    : [100%] Meshing curve 2987 (Extruded)
# Info    : [100%] Meshing curve 3000 (Extruded)
# Info    : [100%] Meshing curve 3001 (Extruded)
# Info    : [100%] Meshing curve 3009 (Extruded)
# Info    : [100%] Meshing curve 3022 (Extruded)
# Info    : [100%] Meshing curve 3023 (Extruded)
# Info    : [100%] Meshing curve 3031 (Extruded)
# Info    : [100%] Meshing curve 3044 (Extruded)
# Info    : [100%] Meshing curve 3045 (Extruded)
# Info    : [100%] Meshing curve 3053 (Extruded)
# Info    : [100%] Meshing curve 3066 (Extruded)
# Info    : [100%] Meshing curve 3067 (Extruded)
# Info    : [100%] Meshing curve 3075 (Extruded)
# Info    : [100%] Meshing curve 3088 (Extruded)
# Info    : [100%] Meshing curve 3089 (Extruded)
# Info    : [100%] Meshing curve 3097 (Extruded)
# Info    : [100%] Meshing curve 3110 (Extruded)
# Info    : [100%] Meshing curve 3111 (Extruded)
# Info    : [100%] Meshing curve 3119 (Extruded)
# Info    : [100%] Meshing curve 3132 (Extruded)
# Info    : [100%] Meshing curve 3133 (Extruded)
# Info    : [100%] Meshing curve 3141 (Extruded)
# Info    : [100%] Meshing curve 3154 (Extruded)
# Info    : [100%] Meshing curve 3155 (Extruded)
# Info    : [100%] Meshing curve 3163 (Extruded)
# Info    : [100%] Meshing curve 3176 (Extruded)
# Info    : [100%] Meshing curve 3177 (Extruded)
# Info    : [100%] Meshing curve 3185 (Extruded)
# Info    : [100%] Meshing curve 3197 (Extruded)
# Info    : [100%] Meshing curve 3198 (Extruded)
# Info    : [100%] Meshing curve 3199 (Extruded)
# Info    : [100%] Meshing curve 3203 (Extruded)
# Info    : [100%] Meshing curve 3207 (Extruded)
# Info    : [100%] Meshing curve 3220 (Extruded)
# Info    : [100%] Meshing curve 3221 (Extruded)
# Info    : [100%] Meshing curve 3229 (Extruded)
# Info    : [100%] Meshing curve 3242 (Extruded)
# Info    : [100%] Meshing curve 3243 (Extruded)
# Info    : [100%] Meshing curve 3251 (Extruded)
# Info    : [100%] Meshing curve 3264 (Extruded)
# Info    : [100%] Meshing curve 3265 (Extruded)
# Info    : [100%] Meshing curve 3273 (Extruded)
# Info    : [100%] Meshing curve 3286 (Extruded)
# Info    : [100%] Meshing curve 3287 (Extruded)
# Info    : [100%] Meshing curve 3295 (Extruded)
# Info    : [100%] Meshing curve 3308 (Extruded)
# Info    : [100%] Meshing curve 3309 (Extruded)
# Info    : [100%] Meshing curve 3317 (Extruded)
# Info    : [100%] Meshing curve 3330 (Extruded)
# Info    : [100%] Meshing curve 3331 (Extruded)
# Info    : [100%] Meshing curve 3339 (Extruded)
# Info    : [100%] Meshing curve 3352 (Extruded)
# Info    : [100%] Meshing curve 3353 (Extruded)
# Info    : [100%] Meshing curve 3361 (Extruded)
# Info    : [100%] Meshing curve 3374 (Extruded)
# Info    : [100%] Meshing curve 3375 (Extruded)
# Info    : [100%] Meshing curve 3383 (Extruded)
# Info    : [100%] Meshing curve 3396 (Extruded)
# Info    : [100%] Meshing curve 3397 (Extruded)
# Info    : [100%] Meshing curve 3405 (Extruded)
# Info    : Done meshing 1D (Wall 0.0291583s, CPU 0.009091s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 10%] Meshing surface 2 (Transfinite)
# Info    : [ 10%] Meshing surface 3 (Transfinite)
# Info    : [ 10%] Meshing surface 4 (Transfinite)
# Info    : [ 10%] Meshing surface 5 (Transfinite)
# Info    : [ 10%] Meshing surface 6 (Transfinite)
# Info    : [ 10%] Meshing surface 7 (Transfinite)
# Info    : [ 10%] Meshing surface 8 (Transfinite)
# Info    : [ 10%] Meshing surface 9 (Transfinite)
# Info    : [ 10%] Meshing surface 10 (Transfinite)
# Info    : [ 10%] Meshing surface 11 (Transfinite)
# Info    : [ 10%] Meshing surface 12 (Transfinite)
# Info    : [ 10%] Meshing surface 13 (Transfinite)
# Info    : [ 10%] Meshing surface 14 (Transfinite)
# Info    : [ 10%] Meshing surface 15 (Transfinite)
# Info    : [ 10%] Meshing surface 16 (Transfinite)
# Info    : [ 10%] Meshing surface 17 (Transfinite)
# Info    : [ 10%] Meshing surface 18 (Transfinite)
# Info    : [ 10%] Meshing surface 19 (Transfinite)
# Info    : [ 10%] Meshing surface 20 (Transfinite)
# Info    : [ 10%] Meshing surface 21 (Transfinite)
# Info    : [ 10%] Meshing surface 22 (Transfinite)
# Info    : [ 10%] Meshing surface 23 (Transfinite)
# Info    : [ 10%] Meshing surface 24 (Transfinite)
# Info    : [ 10%] Meshing surface 25 (Transfinite)
# Info    : [ 10%] Meshing surface 26 (Transfinite)
# Info    : [ 10%] Meshing surface 27 (Transfinite)
# Info    : [ 10%] Meshing surface 28 (Transfinite)
# Info    : [ 10%] Meshing surface 29 (Transfinite)
# Info    : [ 10%] Meshing surface 30 (Transfinite)
# Info    : [ 10%] Meshing surface 31 (Transfinite)
# Info    : [ 10%] Meshing surface 32 (Transfinite)
# Info    : [ 10%] Meshing surface 33 (Transfinite)
# Info    : [ 10%] Meshing surface 34 (Transfinite)
# Info    : [ 10%] Meshing surface 35 (Transfinite)
# Info    : [ 10%] Meshing surface 36 (Transfinite)
# Info    : [ 10%] Meshing surface 37 (Transfinite)
# Info    : [ 10%] Meshing surface 38 (Transfinite)
# Info    : [ 10%] Meshing surface 39 (Transfinite)
# Info    : [ 10%] Meshing surface 40 (Transfinite)
# Info    : [ 10%] Meshing surface 41 (Transfinite)
# Info    : [ 10%] Meshing surface 42 (Transfinite)
# Info    : [ 10%] Meshing surface 43 (Transfinite)
# Info    : [ 10%] Meshing surface 44 (Transfinite)
# Info    : [ 10%] Meshing surface 45 (Transfinite)
# Info    : [ 10%] Meshing surface 46 (Transfinite)
# Info    : [ 10%] Meshing surface 47 (Transfinite)
# Info    : [ 10%] Meshing surface 48 (Transfinite)
# Info    : [ 10%] Meshing surface 49 (Transfinite)
# Info    : [ 10%] Meshing surface 50 (Transfinite)
# Info    : [ 10%] Meshing surface 124 (Transfinite)
# Info    : [ 10%] Meshing surface 128 (Transfinite)
# Info    : [ 10%] Meshing surface 132 (Transfinite)
# Info    : [ 10%] Meshing surface 136 (Transfinite)
# Info    : [ 10%] Meshing surface 137 (Transfinite)
# Info    : [ 20%] Meshing surface 150 (Transfinite)
# Info    : [ 20%] Meshing surface 154 (Transfinite)
# Info    : [ 20%] Meshing surface 158 (Transfinite)
# Info    : [ 20%] Meshing surface 159 (Transfinite)
# Info    : [ 20%] Meshing surface 172 (Transfinite)
# Info    : [ 20%] Meshing surface 176 (Transfinite)
# Info    : [ 20%] Meshing surface 180 (Transfinite)
# Info    : [ 20%] Meshing surface 181 (Transfinite)
# Info    : [ 20%] Meshing surface 194 (Transfinite)
# Info    : [ 20%] Meshing surface 198 (Transfinite)
# Info    : [ 20%] Meshing surface 202 (Transfinite)
# Info    : [ 20%] Meshing surface 203 (Transfinite)
# Info    : [ 20%] Meshing surface 216 (Transfinite)
# Info    : [ 20%] Meshing surface 220 (Transfinite)
# Info    : [ 20%] Meshing surface 224 (Transfinite)
# Info    : [ 20%] Meshing surface 225 (Transfinite)
# Info    : [ 20%] Meshing surface 238 (Transfinite)
# Info    : [ 20%] Meshing surface 242 (Transfinite)
# Info    : [ 20%] Meshing surface 246 (Transfinite)
# Info    : [ 20%] Meshing surface 247 (Transfinite)
# Info    : [ 20%] Meshing surface 260 (Transfinite)
# Info    : [ 20%] Meshing surface 264 (Transfinite)
# Info    : [ 20%] Meshing surface 268 (Transfinite)
# Info    : [ 20%] Meshing surface 269 (Transfinite)
# Info    : [ 20%] Meshing surface 282 (Transfinite)
# Info    : [ 20%] Meshing surface 286 (Transfinite)
# Info    : [ 20%] Meshing surface 290 (Transfinite)
# Info    : [ 20%] Meshing surface 291 (Transfinite)
# Info    : [ 20%] Meshing surface 304 (Transfinite)
# Info    : [ 20%] Meshing surface 308 (Transfinite)
# Info    : [ 20%] Meshing surface 312 (Transfinite)
# Info    : [ 20%] Meshing surface 313 (Transfinite)
# Info    : [ 20%] Meshing surface 326 (Transfinite)
# Info    : [ 20%] Meshing surface 330 (Transfinite)
# Info    : [ 20%] Meshing surface 334 (Transfinite)
# Info    : [ 20%] Meshing surface 335 (Transfinite)
# Info    : [ 20%] Meshing surface 344 (Transfinite)
# Info    : [ 20%] Meshing surface 348 (Transfinite)
# Info    : [ 20%] Meshing surface 352 (Transfinite)
# Info    : [ 20%] Meshing surface 357 (Transfinite)
# Info    : [ 20%] Meshing surface 370 (Transfinite)
# Info    : [ 20%] Meshing surface 374 (Transfinite)
# Info    : [ 20%] Meshing surface 379 (Transfinite)
# Info    : [ 20%] Meshing surface 392 (Transfinite)
# Info    : [ 20%] Meshing surface 396 (Transfinite)
# Info    : [ 20%] Meshing surface 401 (Transfinite)
# Info    : [ 20%] Meshing surface 414 (Transfinite)
# Info    : [ 20%] Meshing surface 418 (Transfinite)
# Info    : [ 20%] Meshing surface 423 (Transfinite)
# Info    : [ 20%] Meshing surface 436 (Transfinite)
# Info    : [ 20%] Meshing surface 440 (Transfinite)
# Info    : [ 20%] Meshing surface 445 (Transfinite)
# Info    : [ 20%] Meshing surface 458 (Transfinite)
# Info    : [ 20%] Meshing surface 462 (Transfinite)
# Info    : [ 30%] Meshing surface 467 (Transfinite)
# Info    : [ 30%] Meshing surface 480 (Transfinite)
# Info    : [ 30%] Meshing surface 484 (Transfinite)
# Info    : [ 30%] Meshing surface 489 (Transfinite)
# Info    : [ 30%] Meshing surface 502 (Transfinite)
# Info    : [ 30%] Meshing surface 506 (Transfinite)
# Info    : [ 30%] Meshing surface 511 (Transfinite)
# Info    : [ 30%] Meshing surface 524 (Transfinite)
# Info    : [ 30%] Meshing surface 528 (Transfinite)
# Info    : [ 30%] Meshing surface 533 (Transfinite)
# Info    : [ 30%] Meshing surface 546 (Transfinite)
# Info    : [ 30%] Meshing surface 550 (Transfinite)
# Info    : [ 30%] Meshing surface 555 (Transfinite)
# Info    : [ 30%] Meshing surface 564 (Transfinite)
# Info    : [ 30%] Meshing surface 568 (Transfinite)
# Info    : [ 30%] Meshing surface 572 (Transfinite)
# Info    : [ 30%] Meshing surface 577 (Transfinite)
# Info    : [ 30%] Meshing surface 590 (Transfinite)
# Info    : [ 30%] Meshing surface 594 (Transfinite)
# Info    : [ 30%] Meshing surface 599 (Transfinite)
# Info    : [ 30%] Meshing surface 612 (Transfinite)
# Info    : [ 30%] Meshing surface 616 (Transfinite)
# Info    : [ 30%] Meshing surface 621 (Transfinite)
# Info    : [ 30%] Meshing surface 634 (Transfinite)
# Info    : [ 30%] Meshing surface 638 (Transfinite)
# Info    : [ 30%] Meshing surface 643 (Transfinite)
# Info    : [ 30%] Meshing surface 656 (Transfinite)
# Info    : [ 30%] Meshing surface 660 (Transfinite)
# Info    : [ 30%] Meshing surface 665 (Transfinite)
# Info    : [ 30%] Meshing surface 678 (Transfinite)
# Info    : [ 30%] Meshing surface 682 (Transfinite)
# Info    : [ 30%] Meshing surface 687 (Transfinite)
# Info    : [ 30%] Meshing surface 700 (Transfinite)
# Info    : [ 30%] Meshing surface 704 (Transfinite)
# Info    : [ 30%] Meshing surface 709 (Transfinite)
# Info    : [ 30%] Meshing surface 722 (Transfinite)
# Info    : [ 30%] Meshing surface 726 (Transfinite)
# Info    : [ 30%] Meshing surface 731 (Transfinite)
# Info    : [ 30%] Meshing surface 744 (Transfinite)
# Info    : [ 30%] Meshing surface 748 (Transfinite)
# Info    : [ 30%] Meshing surface 753 (Transfinite)
# Info    : [ 30%] Meshing surface 766 (Transfinite)
# Info    : [ 30%] Meshing surface 770 (Transfinite)
# Info    : [ 30%] Meshing surface 775 (Transfinite)
# Info    : [ 30%] Meshing surface 784 (Transfinite)
# Info    : [ 30%] Meshing surface 788 (Transfinite)
# Info    : [ 30%] Meshing surface 792 (Transfinite)
# Info    : [ 30%] Meshing surface 797 (Transfinite)
# Info    : [ 30%] Meshing surface 810 (Transfinite)
# Info    : [ 30%] Meshing surface 814 (Transfinite)
# Info    : [ 30%] Meshing surface 819 (Transfinite)
# Info    : [ 30%] Meshing surface 832 (Transfinite)
# Info    : [ 30%] Meshing surface 836 (Transfinite)
# Info    : [ 30%] Meshing surface 841 (Transfinite)
# Info    : [ 30%] Meshing surface 854 (Transfinite)
# Info    : [ 40%] Meshing surface 858 (Transfinite)
# Info    : [ 40%] Meshing surface 863 (Transfinite)
# Info    : [ 40%] Meshing surface 876 (Transfinite)
# Info    : [ 40%] Meshing surface 880 (Transfinite)
# Info    : [ 40%] Meshing surface 885 (Transfinite)
# Info    : [ 40%] Meshing surface 898 (Transfinite)
# Info    : [ 40%] Meshing surface 902 (Transfinite)
# Info    : [ 40%] Meshing surface 907 (Transfinite)
# Info    : [ 40%] Meshing surface 920 (Transfinite)
# Info    : [ 40%] Meshing surface 924 (Transfinite)
# Info    : [ 40%] Meshing surface 929 (Transfinite)
# Info    : [ 40%] Meshing surface 942 (Transfinite)
# Info    : [ 40%] Meshing surface 946 (Transfinite)
# Info    : [ 40%] Meshing surface 951 (Transfinite)
# Info    : [ 40%] Meshing surface 964 (Transfinite)
# Info    : [ 40%] Meshing surface 968 (Transfinite)
# Info    : [ 40%] Meshing surface 973 (Transfinite)
# Info    : [ 40%] Meshing surface 986 (Transfinite)
# Info    : [ 40%] Meshing surface 990 (Transfinite)
# Info    : [ 40%] Meshing surface 995 (Transfinite)
# Info    : [ 40%] Meshing surface 1004 (Transfinite)
# Info    : [ 40%] Meshing surface 1008 (Transfinite)
# Info    : [ 40%] Meshing surface 1012 (Transfinite)
# Info    : [ 40%] Meshing surface 1017 (Transfinite)
# Info    : [ 40%] Meshing surface 1030 (Transfinite)
# Info    : [ 40%] Meshing surface 1034 (Transfinite)
# Info    : [ 40%] Meshing surface 1039 (Transfinite)
# Info    : [ 40%] Meshing surface 1052 (Transfinite)
# Info    : [ 40%] Meshing surface 1056 (Transfinite)
# Info    : [ 40%] Meshing surface 1061 (Transfinite)
# Info    : [ 40%] Meshing surface 1074 (Transfinite)
# Info    : [ 40%] Meshing surface 1078 (Transfinite)
# Info    : [ 40%] Meshing surface 1083 (Transfinite)
# Info    : [ 40%] Meshing surface 1096 (Transfinite)
# Info    : [ 40%] Meshing surface 1100 (Transfinite)
# Info    : [ 40%] Meshing surface 1105 (Transfinite)
# Info    : [ 40%] Meshing surface 1118 (Transfinite)
# Info    : [ 40%] Meshing surface 1122 (Transfinite)
# Info    : [ 40%] Meshing surface 1127 (Transfinite)
# Info    : [ 40%] Meshing surface 1140 (Transfinite)
# Info    : [ 40%] Meshing surface 1144 (Transfinite)
# Info    : [ 40%] Meshing surface 1149 (Transfinite)
# Info    : [ 40%] Meshing surface 1162 (Transfinite)
# Info    : [ 40%] Meshing surface 1166 (Transfinite)
# Info    : [ 40%] Meshing surface 1171 (Transfinite)
# Info    : [ 40%] Meshing surface 1184 (Transfinite)
# Info    : [ 40%] Meshing surface 1188 (Transfinite)
# Info    : [ 40%] Meshing surface 1193 (Transfinite)
# Info    : [ 40%] Meshing surface 1206 (Transfinite)
# Info    : [ 40%] Meshing surface 1210 (Transfinite)
# Info    : [ 40%] Meshing surface 1215 (Transfinite)
# Info    : [ 40%] Meshing surface 1224 (Transfinite)
# Info    : [ 40%] Meshing surface 1228 (Transfinite)
# Info    : [ 40%] Meshing surface 1232 (Transfinite)
# Info    : [ 50%] Meshing surface 1236 (Transfinite)
# Info    : [ 50%] Meshing surface 1237 (Transfinite)
# Info    : [ 50%] Meshing surface 1250 (Transfinite)
# Info    : [ 50%] Meshing surface 1254 (Transfinite)
# Info    : [ 50%] Meshing surface 1258 (Transfinite)
# Info    : [ 50%] Meshing surface 1259 (Transfinite)
# Info    : [ 50%] Meshing surface 1272 (Transfinite)
# Info    : [ 50%] Meshing surface 1276 (Transfinite)
# Info    : [ 50%] Meshing surface 1280 (Transfinite)
# Info    : [ 50%] Meshing surface 1281 (Transfinite)
# Info    : [ 50%] Meshing surface 1294 (Transfinite)
# Info    : [ 50%] Meshing surface 1298 (Transfinite)
# Info    : [ 50%] Meshing surface 1302 (Transfinite)
# Info    : [ 50%] Meshing surface 1303 (Transfinite)
# Info    : [ 50%] Meshing surface 1316 (Transfinite)
# Info    : [ 50%] Meshing surface 1320 (Transfinite)
# Info    : [ 50%] Meshing surface 1324 (Transfinite)
# Info    : [ 50%] Meshing surface 1325 (Transfinite)
# Info    : [ 50%] Meshing surface 1338 (Transfinite)
# Info    : [ 50%] Meshing surface 1342 (Transfinite)
# Info    : [ 50%] Meshing surface 1346 (Transfinite)
# Info    : [ 50%] Meshing surface 1347 (Transfinite)
# Info    : [ 50%] Meshing surface 1360 (Transfinite)
# Info    : [ 50%] Meshing surface 1364 (Transfinite)
# Info    : [ 50%] Meshing surface 1368 (Transfinite)
# Info    : [ 50%] Meshing surface 1369 (Transfinite)
# Info    : [ 50%] Meshing surface 1382 (Transfinite)
# Info    : [ 50%] Meshing surface 1386 (Transfinite)
# Info    : [ 50%] Meshing surface 1390 (Transfinite)
# Info    : [ 50%] Meshing surface 1391 (Transfinite)
# Info    : [ 50%] Meshing surface 1404 (Transfinite)
# Info    : [ 50%] Meshing surface 1408 (Transfinite)
# Info    : [ 50%] Meshing surface 1412 (Transfinite)
# Info    : [ 50%] Meshing surface 1413 (Transfinite)
# Info    : [ 50%] Meshing surface 1426 (Transfinite)
# Info    : [ 50%] Meshing surface 1430 (Transfinite)
# Info    : [ 50%] Meshing surface 1434 (Transfinite)
# Info    : [ 50%] Meshing surface 1435 (Transfinite)
# Info    : [ 50%] Meshing surface 1444 (Transfinite)
# Info    : [ 50%] Meshing surface 1448 (Transfinite)
# Info    : [ 50%] Meshing surface 1452 (Transfinite)
# Info    : [ 50%] Meshing surface 1457 (Transfinite)
# Info    : [ 50%] Meshing surface 1470 (Transfinite)
# Info    : [ 50%] Meshing surface 1474 (Transfinite)
# Info    : [ 50%] Meshing surface 1479 (Transfinite)
# Info    : [ 50%] Meshing surface 1492 (Transfinite)
# Info    : [ 50%] Meshing surface 1496 (Transfinite)
# Info    : [ 50%] Meshing surface 1501 (Transfinite)
# Info    : [ 50%] Meshing surface 1514 (Transfinite)
# Info    : [ 50%] Meshing surface 1518 (Transfinite)
# Info    : [ 50%] Meshing surface 1523 (Transfinite)
# Info    : [ 50%] Meshing surface 1536 (Transfinite)
# Info    : [ 50%] Meshing surface 1540 (Transfinite)
# Info    : [ 50%] Meshing surface 1545 (Transfinite)
# Info    : [ 50%] Meshing surface 1558 (Transfinite)
# Info    : [ 60%] Meshing surface 1562 (Transfinite)
# Info    : [ 60%] Meshing surface 1567 (Transfinite)
# Info    : [ 60%] Meshing surface 1580 (Transfinite)
# Info    : [ 60%] Meshing surface 1584 (Transfinite)
# Info    : [ 60%] Meshing surface 1589 (Transfinite)
# Info    : [ 60%] Meshing surface 1602 (Transfinite)
# Info    : [ 60%] Meshing surface 1606 (Transfinite)
# Info    : [ 60%] Meshing surface 1611 (Transfinite)
# Info    : [ 60%] Meshing surface 1624 (Transfinite)
# Info    : [ 60%] Meshing surface 1628 (Transfinite)
# Info    : [ 60%] Meshing surface 1633 (Transfinite)
# Info    : [ 60%] Meshing surface 1646 (Transfinite)
# Info    : [ 60%] Meshing surface 1650 (Transfinite)
# Info    : [ 60%] Meshing surface 1655 (Transfinite)
# Info    : [ 60%] Meshing surface 1664 (Transfinite)
# Info    : [ 60%] Meshing surface 1668 (Transfinite)
# Info    : [ 60%] Meshing surface 1672 (Transfinite)
# Info    : [ 60%] Meshing surface 1677 (Transfinite)
# Info    : [ 60%] Meshing surface 1690 (Transfinite)
# Info    : [ 60%] Meshing surface 1694 (Transfinite)
# Info    : [ 60%] Meshing surface 1699 (Transfinite)
# Info    : [ 60%] Meshing surface 1712 (Transfinite)
# Info    : [ 60%] Meshing surface 1716 (Transfinite)
# Info    : [ 60%] Meshing surface 1721 (Transfinite)
# Info    : [ 60%] Meshing surface 1734 (Transfinite)
# Info    : [ 60%] Meshing surface 1738 (Transfinite)
# Info    : [ 60%] Meshing surface 1743 (Transfinite)
# Info    : [ 60%] Meshing surface 1756 (Transfinite)
# Info    : [ 60%] Meshing surface 1760 (Transfinite)
# Info    : [ 60%] Meshing surface 1765 (Transfinite)
# Info    : [ 60%] Meshing surface 1778 (Transfinite)
# Info    : [ 60%] Meshing surface 1782 (Transfinite)
# Info    : [ 60%] Meshing surface 1787 (Transfinite)
# Info    : [ 60%] Meshing surface 1800 (Transfinite)
# Info    : [ 60%] Meshing surface 1804 (Transfinite)
# Info    : [ 60%] Meshing surface 1809 (Transfinite)
# Info    : [ 60%] Meshing surface 1822 (Transfinite)
# Info    : [ 60%] Meshing surface 1826 (Transfinite)
# Info    : [ 60%] Meshing surface 1831 (Transfinite)
# Info    : [ 60%] Meshing surface 1844 (Transfinite)
# Info    : [ 60%] Meshing surface 1848 (Transfinite)
# Info    : [ 60%] Meshing surface 1853 (Transfinite)
# Info    : [ 60%] Meshing surface 1866 (Transfinite)
# Info    : [ 60%] Meshing surface 1870 (Transfinite)
# Info    : [ 60%] Meshing surface 1875 (Transfinite)
# Info    : [ 60%] Meshing surface 1884 (Transfinite)
# Info    : [ 60%] Meshing surface 1888 (Transfinite)
# Info    : [ 60%] Meshing surface 1892 (Transfinite)
# Info    : [ 60%] Meshing surface 1897 (Transfinite)
# Info    : [ 60%] Meshing surface 1910 (Transfinite)
# Info    : [ 60%] Meshing surface 1914 (Transfinite)
# Info    : [ 60%] Meshing surface 1919 (Transfinite)
# Info    : [ 60%] Meshing surface 1932 (Transfinite)
# Info    : [ 60%] Meshing surface 1936 (Transfinite)
# Info    : [ 70%] Meshing surface 1941 (Transfinite)
# Info    : [ 70%] Meshing surface 1954 (Transfinite)
# Info    : [ 70%] Meshing surface 1958 (Transfinite)
# Info    : [ 70%] Meshing surface 1963 (Transfinite)
# Info    : [ 70%] Meshing surface 1976 (Transfinite)
# Info    : [ 70%] Meshing surface 1980 (Transfinite)
# Info    : [ 70%] Meshing surface 1985 (Transfinite)
# Info    : [ 70%] Meshing surface 1998 (Transfinite)
# Info    : [ 70%] Meshing surface 2002 (Transfinite)
# Info    : [ 70%] Meshing surface 2007 (Transfinite)
# Info    : [ 70%] Meshing surface 2020 (Transfinite)
# Info    : [ 70%] Meshing surface 2024 (Transfinite)
# Info    : [ 70%] Meshing surface 2029 (Transfinite)
# Info    : [ 70%] Meshing surface 2042 (Transfinite)
# Info    : [ 70%] Meshing surface 2046 (Transfinite)
# Info    : [ 70%] Meshing surface 2051 (Transfinite)
# Info    : [ 70%] Meshing surface 2064 (Transfinite)
# Info    : [ 70%] Meshing surface 2068 (Transfinite)
# ...
# Info    : [ 70%] Meshing surface 2161 (Transfinite)
# Info    : [ 70%] Meshing surface 2174 (Transfinite)
# Info    : [ 70%] Meshing surface 2178 (Transfinite)
# Info    : [ 70%] Meshing surface 2183 (Transfinite)
# Info    : [ 70%] Meshing surface 2196 (Transfinite)
# Info    : [ 70%] Meshing surface 2200 (Transfinite)
# Info    : [ 70%] Meshing surface 2205 (Transfinite)
# Info    : [ 70%] Meshing surface 2218 (Transfinite)
# Info    : [ 70%] Meshing surface 2222 (Transfinite)
# Info    : [ 70%] Meshing surface 2227 (Transfinite)
# Info    : [ 70%] Meshing surface 2240 (Transfinite)
# Info    : [ 70%] Meshing surface 2244 (Transfinite)
# Info    : [ 70%] Meshing surface 2249 (Transfinite)
# Info    : [ 70%] Meshing surface 2262 (Transfinite)
# Info    : [ 70%] Meshing surface 2266 (Transfinite)
# Info    : [ 70%] Meshing surface 2271 (Transfinite)
# Info    : [ 70%] Meshing surface 2284 (Transfinite)
# Info    : [ 70%] Meshing surface 2288 (Transfinite)
# Info    : [ 70%] Meshing surface 2293 (Transfinite)
# Info    : [ 70%] Meshing surface 2306 (Transfinite)
# Info    : [ 70%] Meshing surface 2310 (Transfinite)
# Info    : [ 70%] Meshing surface 2315 (Transfinite)
# Info    : [ 70%] Meshing surface 2324 (Transfinite)
# Info    : [ 70%] Meshing surface 2328 (Transfinite)
# Info    : [ 80%] Meshing surface 2332 (Transfinite)
# Info    : [ 80%] Meshing surface 2336 (Transfinite)
# Info    : [ 80%] Meshing surface 2337 (Transfinite)
# Info    : [ 80%] Meshing surface 2350 (Transfinite)
# Info    : [ 80%] Meshing surface 2354 (Transfinite)
# Info    : [ 80%] Meshing surface 2358 (Transfinite)
# Info    : [ 80%] Meshing surface 2359 (Transfinite)
# Info    : [ 80%] Meshing surface 2372 (Transfinite)
# Info    : [ 80%] Meshing surface 2376 (Transfinite)
# Info    : [ 80%] Meshing surface 2380 (Transfinite)
# Info    : [ 80%] Meshing surface 2381 (Transfinite)
# Info    : [ 80%] Meshing surface 2394 (Transfinite)
# Info    : [ 80%] Meshing surface 2398 (Transfinite)
# Info    : [ 80%] Meshing surface 2402 (Transfinite)
# Info    : [ 80%] Meshing surface 2403 (Transfinite)
# Info    : [ 80%] Meshing surface 2416 (Transfinite)
# Info    : [ 80%] Meshing surface 2420 (Transfinite)
# Info    : [ 80%] Meshing surface 2424 (Transfinite)
# Info    : [ 80%] Meshing surface 2425 (Transfinite)
# Info    : [ 80%] Meshing surface 2438 (Transfinite)
# Info    : [ 80%] Meshing surface 2442 (Transfinite)
# Info    : [ 80%] Meshing surface 2446 (Transfinite)
# Info    : [ 80%] Meshing surface 2447 (Transfinite)
# Info    : [ 80%] Meshing surface 2460 (Transfinite)
# Info    : [ 80%] Meshing surface 2464 (Transfinite)
# Info    : [ 80%] Meshing surface 2468 (Transfinite)
# Info    : [ 80%] Meshing surface 2469 (Transfinite)
# Info    : [ 80%] Meshing surface 2482 (Transfinite)
# Info    : [ 80%] Meshing surface 2486 (Transfinite)
# Info    : [ 80%] Meshing surface 2490 (Transfinite)
# Info    : [ 80%] Meshing surface 2491 (Transfinite)
# Info    : [ 80%] Meshing surface 2504 (Transfinite)
# Info    : [ 80%] Meshing surface 2508 (Transfinite)
# Info    : [ 80%] Meshing surface 2512 (Transfinite)
# Info    : [ 80%] Meshing surface 2513 (Transfinite)
# Info    : [ 80%] Meshing surface 2526 (Transfinite)
# Info    : [ 80%] Meshing surface 2530 (Transfinite)
# Info    : [ 80%] Meshing surface 2534 (Transfinite)
# Info    : [ 80%] Meshing surface 2535 (Transfinite)
# Info    : [ 80%] Meshing surface 2544 (Transfinite)
# Info    : [ 80%] Meshing surface 2548 (Transfinite)
# Info    : [ 80%] Meshing surface 2552 (Transfinite)
# Info    : [ 80%] Meshing surface 2557 (Transfinite)
# Info    : [ 80%] Meshing surface 2570 (Transfinite)
# Info    : [ 80%] Meshing surface 2574 (Transfinite)
# Info    : [ 80%] Meshing surface 2579 (Transfinite)
# Info    : [ 80%] Meshing surface 2592 (Transfinite)
# Info    : [ 80%] Meshing surface 2596 (Transfinite)
# Info    : [ 80%] Meshing surface 2601 (Transfinite)
# Info    : [ 80%] Meshing surface 2614 (Transfinite)
# Info    : [ 80%] Meshing surface 2618 (Transfinite)
# Info    : [ 80%] Meshing surface 2623 (Transfinite)
# Info    : [ 80%] Meshing surface 2636 (Transfinite)
# Info    : [ 80%] Meshing surface 2640 (Transfinite)
# Info    : [ 90%] Meshing surface 2645 (Transfinite)
# Info    : [ 90%] Meshing surface 2658 (Transfinite)
# Info    : [ 90%] Meshing surface 2662 (Transfinite)
# Info    : [ 90%] Meshing surface 2667 (Transfinite)
# Info    : [ 90%] Meshing surface 2680 (Transfinite)
# Info    : [ 90%] Meshing surface 2684 (Transfinite)
# Info    : [ 90%] Meshing surface 2689 (Transfinite)
# Info    : [ 90%] Meshing surface 2702 (Transfinite)
# Info    : [ 90%] Meshing surface 2706 (Transfinite)
# Info    : [ 90%] Meshing surface 2711 (Transfinite)
# Info    : [ 90%] Meshing surface 2724 (Transfinite)
# Info    : [ 90%] Meshing surface 2728 (Transfinite)
# Info    : [ 90%] Meshing surface 2733 (Transfinite)
# Info    : [ 90%] Meshing surface 2746 (Transfinite)
# Info    : [ 90%] Meshing surface 2750 (Transfinite)
# Info    : [ 90%] Meshing surface 2755 (Transfinite)
# Info    : [ 90%] Meshing surface 2764 (Transfinite)
# Info    : [ 90%] Meshing surface 2768 (Transfinite)
# Info    : [ 90%] Meshing surface 2772 (Transfinite)
# Info    : [ 90%] Meshing surface 2777 (Transfinite)
# Info    : [ 90%] Meshing surface 2790 (Transfinite)
# Info    : [ 90%] Meshing surface 2794 (Transfinite)
# Info    : [ 90%] Meshing surface 2799 (Transfinite)
# Info    : [ 90%] Meshing surface 2812 (Transfinite)
# Info    : [ 90%] Meshing surface 2816 (Transfinite)
# Info    : [ 90%] Meshing surface 2821 (Transfinite)
# Info    : [ 90%] Meshing surface 2834 (Transfinite)
# Info    : [ 90%] Meshing surface 2838 (Transfinite)
# Info    : [ 90%] Meshing surface 2843 (Transfinite)
# Info    : [ 90%] Meshing surface 2856 (Transfinite)
# Info    : [ 90%] Meshing surface 2860 (Transfinite)
# Info    : [ 90%] Meshing surface 2865 (Transfinite)
# Info    : [ 90%] Meshing surface 2878 (Transfinite)
# Info    : [ 90%] Meshing surface 2882 (Transfinite)
# Info    : [ 90%] Meshing surface 2887 (Transfinite)
# Info    : [ 90%] Meshing surface 2900 (Transfinite)
# Info    : [ 90%] Meshing surface 2904 (Transfinite)
# Info    : [ 90%] Meshing surface 2909 (Transfinite)
# Info    : [ 90%] Meshing surface 2922 (Transfinite)
# Info    : [ 90%] Meshing surface 2926 (Transfinite)
# Info    : [ 90%] Meshing surface 2931 (Transfinite)
# Info    : [ 90%] Meshing surface 2944 (Transfinite)
# Info    : [ 90%] Meshing surface 2948 (Transfinite)
# Info    : [ 90%] Meshing surface 2953 (Transfinite)
# Info    : [ 90%] Meshing surface 2966 (Transfinite)
# Info    : [ 90%] Meshing surface 2970 (Transfinite)
# Info    : [ 90%] Meshing surface 2975 (Transfinite)
# Info    : [ 90%] Meshing surface 2984 (Transfinite)
# Info    : [ 90%] Meshing surface 2988 (Transfinite)
# Info    : [ 90%] Meshing surface 2992 (Transfinite)
# Info    : [ 90%] Meshing surface 2997 (Transfinite)
# Info    : [ 90%] Meshing surface 3010 (Transfinite)
# Info    : [ 90%] Meshing surface 3014 (Transfinite)
# Info    : [ 90%] Meshing surface 3019 (Transfinite)
# Info    : [ 90%] Meshing surface 3032 (Transfinite)
# Info    : [100%] Meshing surface 3036 (Transfinite)
# Info    : [100%] Meshing surface 3041 (Transfinite)
# Info    : [100%] Meshing surface 3054 (Transfinite)
# Info    : [100%] Meshing surface 3058 (Transfinite)
# Info    : [100%] Meshing surface 3063 (Transfinite)
# Info    : [100%] Meshing surface 3076 (Transfinite)
# Info    : [100%] Meshing surface 3080 (Transfinite)
# Info    : [100%] Meshing surface 3085 (Transfinite)
# Info    : [100%] Meshing surface 3098 (Transfinite)
# Info    : [100%] Meshing surface 3102 (Transfinite)
# Info    : [100%] Meshing surface 3107 (Transfinite)
# Info    : [100%] Meshing surface 3120 (Transfinite)
# Info    : [100%] Meshing surface 3124 (Transfinite)
# Info    : [100%] Meshing surface 3129 (Transfinite)
# Info    : [100%] Meshing surface 3142 (Transfinite)
# Info    : [100%] Meshing surface 3146 (Transfinite)
# Info    : [100%] Meshing surface 3151 (Transfinite)
# Info    : [100%] Meshing surface 3164 (Transfinite)
# Info    : [100%] Meshing surface 3168 (Transfinite)
# Info    : [100%] Meshing surface 3173 (Transfinite)
# Info    : [100%] Meshing surface 3186 (Transfinite)
# Info    : [100%] Meshing surface 3190 (Transfinite)
# Info    : [100%] Meshing surface 3195 (Transfinite)
# Info    : [100%] Meshing surface 3204 (Transfinite)
# Info    : [100%] Meshing surface 3208 (Transfinite)
# Info    : [100%] Meshing surface 3212 (Transfinite)
# Info    : [100%] Meshing surface 3217 (Transfinite)
# Info    : [100%] Meshing surface 3230 (Transfinite)
# Info    : [100%] Meshing surface 3234 (Transfinite)
# Info    : [100%] Meshing surface 3239 (Transfinite)
# Info    : [100%] Meshing surface 3252 (Transfinite)
# Info    : [100%] Meshing surface 3256 (Transfinite)
# Info    : [100%] Meshing surface 3261 (Transfinite)
# Info    : [100%] Meshing surface 3274 (Transfinite)
# Info    : [100%] Meshing surface 3278 (Transfinite)
# Info    : [100%] Meshing surface 3283 (Transfinite)
# Info    : [100%] Meshing surface 3296 (Transfinite)
# Info    : [100%] Meshing surface 3300 (Transfinite)
# Info    : [100%] Meshing surface 3305 (Transfinite)
# Info    : [100%] Meshing surface 3318 (Transfinite)
# Info    : [100%] Meshing surface 3322 (Transfinite)
# Info    : [100%] Meshing surface 3327 (Transfinite)
# Info    : [100%] Meshing surface 3340 (Transfinite)
# Info    : [100%] Meshing surface 3344 (Transfinite)
# Info    : [100%] Meshing surface 3349 (Transfinite)
# Info    : [100%] Meshing surface 3362 (Transfinite)
# Info    : [100%] Meshing surface 3366 (Transfinite)
# Info    : [100%] Meshing surface 3371 (Transfinite)
# Info    : [100%] Meshing surface 3384 (Transfinite)
# Info    : [100%] Meshing surface 3388 (Transfinite)
# Info    : [100%] Meshing surface 3393 (Transfinite)
# Info    : [100%] Meshing surface 3406 (Transfinite)
# Info    : [100%] Meshing surface 3410 (Transfinite)
# Info    : [100%] Meshing surface 3415 (Transfinite)
# Info    : Done meshing 2D (Wall 0.230776s, CPU 0.061969s)
# Info    : Meshing 3D...
# Info    : Meshing volume 1 (Extruded)
# Info    : Meshing volume 2 (Extruded)
# Info    : Meshing volume 3 (Extruded)
# Info    : Meshing volume 4 (Extruded)
# Info    : Meshing volume 5 (Extruded)
# Info    : Meshing volume 6 (Extruded)
# Info    : Meshing volume 7 (Extruded)
# Info    : Meshing volume 8 (Extruded)
# Info    : Meshing volume 9 (Extruded)
# Info    : Meshing volume 10 (Extruded)
# Info    : Meshing volume 11 (Extruded)
# Info    : Meshing volume 12 (Extruded)
# Info    : Meshing volume 13 (Extruded)
# Info    : Meshing volume 14 (Extruded)
# Info    : Meshing volume 15 (Extruded)
# Info    : Meshing volume 16 (Extruded)
# Info    : Meshing volume 17 (Extruded)
# Info    : Meshing volume 18 (Extruded)
# Info    : Meshing volume 19 (Extruded)
# Info    : Meshing volume 20 (Extruded)
# Info    : Meshing volume 21 (Extruded)
# Info    : Meshing volume 22 (Extruded)
# Info    : Meshing volume 23 (Extruded)
# Info    : Meshing volume 24 (Extruded)
# Info    : Meshing volume 25 (Extruded)
# Info    : Meshing volume 26 (Extruded)
# Info    : Meshing volume 27 (Extruded)
# Info    : Meshing volume 28 (Extruded)
# Info    : Meshing volume 29 (Extruded)
# Info    : Meshing volume 30 (Extruded)
# Info    : Meshing volume 31 (Extruded)
# Info    : Meshing volume 32 (Extruded)
# Info    : Meshing volume 33 (Extruded)
# Info    : Meshing volume 34 (Extruded)
# Info    : Meshing volume 35 (Extruded)
# Info    : Meshing volume 36 (Extruded)
# Info    : Meshing volume 37 (Extruded)
# Info    : Meshing volume 38 (Extruded)
# Info    : Meshing volume 39 (Extruded)
# Info    : Meshing volume 40 (Extruded)
# Info    : Meshing volume 41 (Extruded)
# Info    : Meshing volume 42 (Extruded)
# Info    : Meshing volume 43 (Extruded)
# Info    : Meshing volume 44 (Extruded)
# Info    : Meshing volume 45 (Extruded)
# Info    : Meshing volume 46 (Extruded)
# Info    : Meshing volume 47 (Extruded)
# Info    : Meshing volume 48 (Extruded)
# Info    : Meshing volume 49 (Extruded)
# Info    : Meshing volume 50 (Extruded)
# Info    : Meshing volume 51 (Extruded)
# Info    : Meshing volume 52 (Extruded)
# Info    : Meshing volume 53 (Extruded)
# Info    : Meshing volume 54 (Extruded)
# Info    : Meshing volume 55 (Extruded)
# Info    : Meshing volume 56 (Extruded)
# Info    : Meshing volume 57 (Extruded)
# Info    : Meshing volume 58 (Extruded)
# Info    : Meshing volume 59 (Extruded)
# Info    : Meshing volume 60 (Extruded)
# Info    : Meshing volume 61 (Extruded)
# Info    : Meshing volume 62 (Extruded)
# Info    : Meshing volume 63 (Extruded)
# Info    : Meshing volume 64 (Extruded)
# Info    : Meshing volume 65 (Extruded)
# Info    : Meshing volume 66 (Extruded)
# Info    : Meshing volume 67 (Extruded)
# Info    : Meshing volume 68 (Extruded)
# Info    : Meshing volume 69 (Extruded)
# Info    : Meshing volume 70 (Extruded)
# Info    : Meshing volume 71 (Extruded)
# Info    : Meshing volume 72 (Extruded)
# Info    : Meshing volume 73 (Extruded)
# Info    : Meshing volume 74 (Extruded)
# Info    : Meshing volume 75 (Extruded)
# Info    : Meshing volume 76 (Extruded)
# Info    : Meshing volume 77 (Extruded)
# Info    : Meshing volume 78 (Extruded)
# Info    : Meshing volume 79 (Extruded)
# Info    : Meshing volume 80 (Extruded)
# Info    : Meshing volume 81 (Extruded)
# Info    : Meshing volume 82 (Extruded)
# Info    : Meshing volume 83 (Extruded)
# Info    : Meshing volume 84 (Extruded)
# Info    : Meshing volume 85 (Extruded)
# Info    : Meshing volume 86 (Extruded)
# Info    : Meshing volume 87 (Extruded)
# Info    : Meshing volume 88 (Extruded)
# Info    : Meshing volume 89 (Extruded)
# Info    : Meshing volume 90 (Extruded)
# Info    : Meshing volume 91 (Extruded)
# Info    : Meshing volume 92 (Extruded)
# Info    : Meshing volume 93 (Extruded)
# Info    : Meshing volume 94 (Extruded)
# Info    : Meshing volume 95 (Extruded)
# Info    : Meshing volume 96 (Extruded)
# Info    : Meshing volume 97 (Extruded)
# Info    : Meshing volume 98 (Extruded)
# Info    : Meshing volume 99 (Extruded)
# Info    : Meshing volume 100 (Extruded)
# Info    : Meshing volume 101 (Extruded)
# Info    : Meshing volume 102 (Extruded)
# Info    : Meshing volume 103 (Extruded)
# Info    : Meshing volume 104 (Extruded)
# Info    : Meshing volume 105 (Extruded)
# Info    : Meshing volume 106 (Extruded)
# Info    : Meshing volume 107 (Extruded)
# Info    : Meshing volume 108 (Extruded)
# Info    : Meshing volume 109 (Extruded)
# Info    : Meshing volume 110 (Extruded)
# Info    : Meshing volume 111 (Extruded)
# Info    : Meshing volume 112 (Extruded)
# Info    : Meshing volume 113 (Extruded)
# Info    : Meshing volume 114 (Extruded)
# Info    : Meshing volume 115 (Extruded)
# Info    : Meshing volume 116 (Extruded)
# Info    : Meshing volume 117 (Extruded)
# Info    : Meshing volume 118 (Extruded)
# Info    : Meshing volume 119 (Extruded)
# Info    : Meshing volume 120 (Extruded)
# Info    : Meshing volume 121 (Extruded)
# Info    : Meshing volume 122 (Extruded)
# Info    : Meshing volume 123 (Extruded)
# Info    : Meshing volume 124 (Extruded)
# Info    : Meshing volume 125 (Extruded)
# Info    : Meshing volume 126 (Extruded)
# Info    : Meshing volume 127 (Extruded)
# Info    : Meshing volume 128 (Extruded)
# Info    : Meshing volume 129 (Extruded)
# Info    : Meshing volume 130 (Extruded)
# Info    : Meshing volume 131 (Extruded)
# Info    : Meshing volume 132 (Extruded)
# Info    : Meshing volume 133 (Extruded)
# Info    : Meshing volume 134 (Extruded)
# Info    : Meshing volume 135 (Extruded)
# Info    : Meshing volume 136 (Extruded)
# Info    : Meshing volume 137 (Extruded)
# Info    : Meshing volume 138 (Extruded)
# Info    : Meshing volume 139 (Extruded)
# Info    : Meshing volume 140 (Extruded)
# Info    : Meshing volume 141 (Extruded)
# Info    : Meshing volume 142 (Extruded)
# Info    : Meshing volume 143 (Extruded)
# Info    : Meshing volume 144 (Extruded)
# Info    : Meshing volume 145 (Extruded)
# Info    : Meshing volume 146 (Extruded)
# Info    : Meshing volume 147 (Extruded)
# Info    : Meshing volume 148 (Extruded)
# Info    : Meshing volume 149 (Extruded)
# Info    : Meshing volume 150 (Extruded)
# Info    : Done meshing 3D (Wall 2.33373s, CPU 1.38364s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.0145844s, CPU 0.014357s)
# Info    : 374016 nodes 496503 elements
# Info    : Writing 'Coil3DVelocityAV.msh'...
# Info    : Done writing 'Coil3DVelocityAV.msh'

# %% [markdown]
# ### Load Results
# For the validation the magnetic flux through the pole face and the electric current through the symmetrie plane in the region of the pole are compared. Additionally the fieldresults along a line in z-directions inside the moving conductor are compared.
# #### openCFS

# %%
# Load magnetic Flux
with open("history/Coil3DVelocityAV-magFlux-surfRegion-flux.csv", "r") as f:
    lines = f.readlines()
    
# Skip header
data = np.array([line.strip().split(",") for line in lines[1:]],dtype=float)
openCFS_Flux = np.abs(data[0,1])

# Load Current
with open("history/Coil3DVelocityAV-magTotalCurrent-surfRegion-current.csv", "r") as f:
    lines = f.readlines()
    
# Skip header
data = np.array([line.strip().split(",") for line in lines[1:]],dtype=float)

openCFS_Current = np.abs(data[0,1])

# Read Sensor Array
openCFS_lineResult_Flux = SensorArray("sensorArray/flux_rail.csv-1")
openCFS_lineResult_Current = SensorArray("sensorArray/current_rail.csv-1")

# %% [markdown]
# #### Opera

# %%
# Global reference Solution 
opera = pd.read_csv("operaSolution_global.txt", delimiter=";", decimal=",", skipinitialspace=True)
opera_Flux = np.abs(float(opera.loc[0,"Flux"]))
opera_Current = np.abs(float(opera.loc[0,"Current"]))

# Read Line Results
opera_lineResults = OperaTable("operaSolution_lineResults.table")

# %% [markdown]
# ### Comparison
# #### Global Results

# %%
differenceFlux = openCFS_Flux - opera_Flux
differenceCurrent = openCFS_Current - opera_Current
relDifferenceFlux = differenceFlux/opera_Flux
relDifferenceCurrent = differenceCurrent/opera_Current
# Create a DataFrame with the results
data = {
    "openCFS": [openCFS_Flux, openCFS_Current],
    "Opera": [opera_Flux, opera_Current],
    "Difference": [differenceFlux, differenceCurrent],
    "relDifference in %": [relDifferenceFlux*100, relDifferenceCurrent*100]
}

# Define row labels
index_labels = ["Flux", "Current"]

# Create the DataFrame
df = pd.DataFrame(data, index=index_labels)

# Display the table
display(df)
# Out:
#           openCFS     Opera    Difference  relDifference in %
# Flux     0.000006  0.000006 -4.041181e-08           -0.695167
# Current  0.862553  0.868895 -6.341771e-03           -0.729866

# %% [markdown]
# #### Line Results

# %%
for j, component in enumerate(["B_x", "B_y", "B_z", "J_x", "J_y", "J_z"]):
    # Erstelle Subplots (eine Zeile mit N_velocities Spalten)
    fig, ax = plt.subplots(1, 1, figsize=(6.5, 5))
    ax.plot(1E3*opera_lineResults["Z"],opera_lineResults[component.replace("_", "")], linestyle='-',label=f"Opera")

    if j < 3: 
        cfsData = openCFS_lineResult_Flux
        unitStr = "Vs"
    elif j < 6: 
        cfsData = openCFS_lineResult_Current
        unitStr = "A/m²"
    cfsCoordinates = cfsData.getNodeCoordinates()
    ax.plot(1E3*cfsCoordinates[:,2],cfsData.RealValue[:,j%3], linestyle='-',label=f"openCFS")

    ax.set_xlabel("z in mm")
    ax.grid()
    if j < 3:
        ax.set_ylim(-0.2,0.2)
    elif j <6:
        ax.set_ylim(-26E4,26E4)
        ax.yaxis.set_major_formatter(ticker.ScalarFormatter(useMathText=True))
        ax.ticklabel_format(style='sci', axis='y', scilimits=(4,4))  # Erzwingt 1e4-Format
    ax.legend()
    
    

    # Gemeinsame y-Achsen-Beschriftung für alle Subplots
    fig.supylabel(f"${component}$ in {unitStr}")

    # Layout anpassen und Plot anzeigen
    fig.tight_layout()
    fig.subplots_adjust(left=0.15)
    plt.show()
